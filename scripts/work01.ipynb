# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/NFFA-SEM/scripts'
# Out:
# train2-yaml.py	train.ipynb  train.py  train-yaml.py  Untitled0.ipynb

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/NFFA-SEM/scripts/train.py'
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 90.1MB/s]
# Epoch 1/10 | Train Loss: 0.9255 | Train Acc: 0.7158
# Validation Acc: 0.6620
# Epoch 2/10 | Train Loss: 0.5494 | Train Acc: 0.8298
# Validation Acc: 0.8873
# Epoch 3/10 | Train Loss: 0.3351 | Train Acc: 0.8930
# Validation Acc: 0.9155
# Epoch 4/10 | Train Loss: 0.3303 | Train Acc: 0.8895
# Validation Acc: 0.9155
# Epoch 5/10 | Train Loss: 0.2720 | Train Acc: 0.9070
# Validation Acc: 0.8732
# Epoch 6/10 | Train Loss: 0.2375 | Train Acc: 0.9246
# Validation Acc: 0.8310
# Epoch 7/10 | Train Loss: 0.3235 | Train Acc: 0.8965
# Validation Acc: 0.8169
# Epoch 8/10 | Train Loss: 0.2756 | Train Acc: 0.9123
# Validation Acc: 0.8451
# Epoch 9/10 | Train Loss: 0.1928 | Train Acc: 0.9281
# Validation Acc: 0.8873
# Epoch 10/10 | Train Loss: 0.1853 | Train Acc: 0.9368
# Validation Acc: 0.9155
# Test Accuracy: 0.7917
# Model saved!
# Figure(640x480)
# Figure(640x480)
